# %%
# use anaconda when running jupyter notebook
# go to the folder/directory on jupyter and click on New
# run by pressing shift + return on mac

import pandas as pd

# %%
# read the csv in
# dataframe is basically rows and columns

df = pd.read_csv('/Users/jean110284/Desktop/Everything/MJUPython/survey_results_public.csv')

# %%
df.head(2)
# Out:
#    ResponseId                              MainBranch  \
# 0           1          I am a developer by profession
# 1           2  I am a student who is learning to code
#
#                                           Employment      Country US_State  \
# 0  Independent contractor, freelancer, or self-em...     Slovakia      NaN
# 1                                 Student, full-time  Netherlands      NaN
#
#   UK_Country                                            EdLevel  \
# 0        NaN  Secondary school (e.g. American high school, G...
# 1        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#       Age1stCode                                          LearnCode YearsCode  \
# 0  18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...       NaN
# 1  11 - 17 years  Other online resources (ex: videos, blogs, etc...         7
#
#    ...              Age Gender Trans                Sexuality  \
# 0  ...  25-34 years old    Man    No  Straight / Heterosexual
# ...

# %%
# make ResponseId as the index column
# but need to check if all indexes are unique

print(df['ResponseId'].value_counts())
# Out:
# 1        1
# 55614    1
# 55632    1
# 55631    1
# 55630    1
#         ..
# 27812    1
# 27811    1
# 27810    1
# 27809    1
# 83439    1
# Name: ResponseId, Length: 83439, dtype: int64

# %%
# check if each row on ResponseId column has a duplicate

df.ResponseId.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 83434    False
# 83435    False
# 83436    False
# 83437    False
# 83438    False
# Name: ResponseId, Length: 83439, dtype: bool

# %%
# how to count duplicated values in a column
# since there is no duplicate value on response Id column
# we can make it as our index column

df.ResponseId.duplicated().sum()
# Out:
# 0

# %%
# set the ResponseId as the index column

df = pd.read_csv('/Users/jean110284/Desktop/Everything/MJUPython/survey_results_public.csv', index_col = 'ResponseId')

# %%
df.head(2)
# Out:
#                                         MainBranch  \
# ResponseId
# 1                   I am a developer by profession
# 2           I am a student who is learning to code
#
#                                                    Employment      Country  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...     Slovakia
# 2                                          Student, full-time  Netherlands
#
#            US_State UK_Country  \
# ResponseId
# 1               NaN        NaN
# 2               NaN        NaN
#
#                                                       EdLevel     Age1stCode  \
# ResponseId
# 1           Secondary school (e.g. American high school, G...  18 - 24 years
# 2                Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
#
#                                                     LearnCode YearsCode  \
# ResponseId
# 1           Coding Bootcamp;Other online resources (ex: vi...       NaN
# ...

# %%
# how do we know our number of rows and columns?
# df.shape is an attribute, not a method so no need to put a ()

df.shape
# Out:
# (83439, 47)

# %%
# if you wanted more information, use the info method, 
# to give you all the number of rows and columns and all other details
# this is a method
# range index - number of rows
# int64 are just integer and float are decimal numbers
# convertedcompyearly is in object, need to convert to float

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83439 entries, 1 to 83439
# Data columns (total 47 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    83439 non-null  object
#  1   Employment                    83323 non-null  object
#  2   Country                       83439 non-null  object
#  3   US_State                      14920 non-null  object
#  4   UK_Country                    4418 non-null   object
#  5   EdLevel                       83126 non-null  object
#  6   Age1stCode                    83243 non-null  object
#  7   LearnCode                     82963 non-null  object
#  8   YearsCode                     81641 non-null  object
#  9   YearsCodePro                  61216 non-null  object
#  10  DevType                       66484 non-null  object
#  11  OrgSize                       60726 non-null  object
# ...

# %%
# Count the NaN under a single DataFrame column: ConvertedCompYearly

df['ConvertedCompYearly'].isnull().sum()
# Out:
# 36595

# %%
# Boolean way of checking Nan Value under a single data frame column

df['ConvertedCompYearly'].isnull().values.any()
# Out:
# True

# %%
# Check for NaN under an entire DataFrame:
    
df.isnull().values.any()
# Out:
# True

# %%
#  Count the NaN under an entire DataFrame:

df.isnull().sum().sum()
# Out:
# 689972

# %%
# change the setting to see all the columns

pd.set_option('display.max_column', 85)
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
# if we want to know what type of question each column has then import the schema

schema_df = pd.read_csv('/Users/jean110284/Desktop/Everything/MJUPython/survey_results_schema.csv')

# %%
schema_df
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# ...

# %%
# if we want to view all of the rows and columns
# must include also rows
# change the setting to see all the columns

pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
schema_df
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# ...

# %%
# check the head of dataframe

df.head(3)
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
#
#                        Country US_State UK_Country  \
# ResponseId
# 1                     Slovakia      NaN        NaN
# 2                  Netherlands      NaN        NaN
# 3           Russian Federation      NaN        NaN
#
#                                                       EdLevel     Age1stCode  \
# ResponseId
# 1           Secondary school (e.g. American high school, G...  18 - 24 years
# ...

# %%
# if you want to see the last rows, will give the last 10 as default

df.tail()
# Out:
#                                 MainBranch  \
# ResponseId
# 83435       I am a developer by profession
# 83436       I am a developer by profession
# 83437       I am a developer by profession
# 83438       I am a developer by profession
# 83439       I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 83435                                      Employed full-time
# 83436       Independent contractor, freelancer, or self-em...
# 83437                                      Employed full-time
# 83438                                      Employed full-time
# 83439                                      Employed full-time
#
#                              Country    US_State UK_Country  \
# ResponseId
# 83435       United States of America       Texas        NaN
# 83436                          Benin         NaN        NaN
# 83437       United States of America  New Jersey        NaN
# ...

# %%
# remove unnecessary columns
# first, check the available columns

df.columns
# Out:
# Index(['MainBranch', 'Employment', 'Country', 'US_State', 'UK_Country',
#        'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode', 'YearsCodePro',
#        'DevType', 'OrgSize', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
# drop the unnecessary columns

df.drop(columns= ['UK_Country','YearsCodePro','Currency','CompTotal','CompFreq','SOComm','NEWOtherComms','Ethnicity','Accessibility','SurveyLength','SurveyEase'])
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83439 entries, 1 to 83439
# Data columns (total 47 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    83439 non-null  object
#  1   Employment                    83323 non-null  object
#  2   Country                       83439 non-null  object
#  3   US_State                      14920 non-null  object
#  4   UK_Country                    4418 non-null   object
#  5   EdLevel                       83126 non-null  object
#  6   Age1stCode                    83243 non-null  object
#  7   LearnCode                     82963 non-null  object
#  8   YearsCode                     81641 non-null  object
#  9   YearsCodePro                  61216 non-null  object
#  10  DevType                       66484 non-null  object
#  11  OrgSize                       60726 non-null  object
# ...

# %%
# we can see that the ConvertedCompYearly has been converted to float
# formula: df['column name'] = df['column name'].astype(float)
# do not convert NaN to zero as NaN means empty, convert it to float instead
# incase it is required to be converted to zero, use: df.fillna('any value')
# it this case, ConvertedCompYearly shouldn't be converted to zero

# %%
# drop the unnecessary columns permanently
# put inplace = True

df.drop(columns= ['UK_Country','YearsCodePro','Currency','CompTotal','CompFreq','SOComm','NEWOtherComms','Ethnicity','Accessibility','SurveyLength','SurveyEase'], inplace = True)
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
# rename some columns using the rename methhod
# pass in a dictionary for the column that we want to change
# the key would be the old value, the value would be the new value

df.rename(columns = {'MainBranch':'MainProfession','ConvertedCompYearly':'YearlySalary'})
# Out:
#                                                MainProfession  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
# if you are satisfied with the new column names, make it permanent
# use inplace = True

df.rename(columns = {'MainBranch':'MainProfession','ConvertedCompYearly':'YearlySalary'},inplace=True)

# %%
# filter the MainProfession column with 'developer' word
# put it in a variable first (filt)
# put Na so it will not result to an error

filt = df['MainProfession'].str.contains('developer',na=False)

# %%
# then perform filter function

df.loc[filt,'MainProfession']
# Out:
# ResponseId
# 1                           I am a developer by profession
# 3        I am not primarily a developer, but I write co...
# 4                           I am a developer by profession
# 5                           I am a developer by profession
# 9                           I am a developer by profession
#                                ...
# 83435                       I am a developer by profession
# 83436                       I am a developer by profession
# 83437                       I am a developer by profession
# 83438                       I am a developer by profession
# 83439                       I am a developer by profession
# Name: MainProfession, Length: 65968, dtype: object

# %%
# count how many rows have developer

df.loc[filt,'MainProfession'].count()
# Out:
# 65968

# %%
df.shape
# Out:
# (83439, 36)

# %%
# therefore there are 65968 developers / 83439 respondents
# plot this using a pie chart
# source: https://www.youtube.com/watch?v=GOuUGWGUT14

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
Count = [65968,83439]
MainProfession =["Developers","TotalRespondents"]

# %%
plt.pie(Count,labels=MainProfession)
# to make shape flat
plt.axis = ("equal")
# to get rid of extra labels
plt.show()

# %%
# if you want to increase the radius of the chart
# if you want the numerical label ('%0.0f%%' for zero decimal place)
# can also use explode to make other pies come out (explode = [0,0])
# by default the angle starts at 0 degree and counterclockwise, 
# so explode = [0,0], will start with the developer first, then counterclockwise
# always use plt.show() to remove extra labels
 
plt.pie(Count,labels=MainProfession, radius = 1.5, autopct = '%0.2f%%', shadow = True, explode = [0.1,0])
plt.show()

# %%
# if you want to change the start angle use radius

colors= ['pink', 'green']
plt.title('Developers Ratio', loc = 'center', color = 'black')
plt.pie(Count,labels=MainProfession, radius = 1, autopct = '%0.2f%%', shadow = True, explode = [0.1,0], startangle = 45, colors = colors)
plt.show()

# %%
student = df['MainProfession'].str.contains('student',na=False)

# %%
df.loc[student,'MainProfession'].count()
# Out:
# 12029

# %%
sometimes = df['MainProfession'].str.contains('sometimes',na=False)

# %%
df.loc[sometimes,'MainProfession'].count()
# Out:
# 6578

# %%
hobby = df['MainProfession'].str.contains('hobby',na=False)

# %%
df.loc[hobby,'MainProfession'].count()
# Out:
# 4929

# %%
used_to_be = df['MainProfession'].str.contains('used',na=False)

# %%
df.loc[used_to_be,'MainProfession'].count()
# Out:
# 1237

# %%
df['MainProfession'].value_counts()
# Out:
# I am a developer by profession                                                   58153
# I am a student who is learning to code                                           12029
# I am not primarily a developer, but I write code sometimes as part of my work     6578
# I code primarily as a hobby                                                       4929
# I used to be a developer by profession, but no longer am                          1237
# None of these                                                                      513
# Name: MainProfession, dtype: int64

# %%
df.head(2)
# Out:
#                                     MainProfession  \
# ResponseId
# 1                   I am a developer by profession
# 2           I am a student who is learning to code
#
#                                                    Employment      Country  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...     Slovakia
# 2                                          Student, full-time  Netherlands
#
#            US_State                                            EdLevel  \
# ResponseId
# 1               NaN  Secondary school (e.g. American high school, G...
# 2               NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                Age1stCode                                          LearnCode  \
# ResponseId
# 1           18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 2           11 - 17 years  Other online resources (ex: videos, blogs, etc...
#
#            YearsCode            DevType             OrgSize  \
# ResponseId
# ...

# %%
# Create a New Pie Chart

Count = [58153,12029,6578,4929,1237]
MainProfession =["Developers","Student","NotAPrimaryDev","CodeAsHobby","FormerDev"]
colors= ['pink', 'rosybrown', 'lightcoral','indianred','salmon']
plt.title('Main Profession', loc = 'center', color = 'black')
plt.pie(Count,labels=MainProfession, radius = 1, autopct = '%0.2f%%', shadow = True, explode = [0,0,0,0,0], startangle = 0, colors = colors)
plt.show()

# %%
df['Employment'].value_counts()
# Out:
# Employed full-time                                      53584
# Student, full-time                                      11781
# Independent contractor, freelancer, or self-employed     8041
# Not employed, but looking for work                       2961
# Employed part-time                                       2461
# Student, part-time                                       2051
# Not employed, and not looking for work                   1228
# I prefer not to say                                       890
# Retired                                                   326
# Name: Employment, dtype: int64

# %%
# generate the pie chart of main profession

Count = [53584,11781,8041,2961,2461,2051,1228,890,890]
EmploymentType =["Employed","Student","Independent Contractor","Unemployed","PartTime Employed","PartTime Student","Unemployed","PreferNotToSay","Retired"]
colors= ['pink', 'rosybrown', 'lightcoral','indianred','salmon']
plt.title('Main Profession', loc = 'center', color = 'black')
plt.pie(Count,labels=EmploymentType, radius = 1, autopct = '%0.2f%%', shadow = True, explode = [0,0,0,0,0,0,0,0,0], startangle = 0, colors = colors)
plt.show()

# %%
# get the top 10 countries
# can also use
# plt.rcParams["figure.figsize"] = [7.50, 3.50]
# plt.rcParams["figure.autolayout"] = True

color = ['r', 'g', 'b','y','r', 'g', 'b','y','r','b']

#head(20) is for the font
top10 = df['Country'].value_counts().head(10).sort_values(ascending=False).head(20).plot(kind='bar',color=color)

# label a bar plot
top10.bar_label(top10.containers[0], label_type='edge', color='black', rotation=0, fontsize=10, padding=3)


plt.title("Top 10 Countries")
plt.rcParams["figure.figsize"] = [7.50, 8.50]
plt.xlabel("Countries")
plt.ylabel("Count")
plt.show()

# %%
df.head(2)
# Out:
#                                     MainProfession  \
# ResponseId
# 1                   I am a developer by profession
# 2           I am a student who is learning to code
#
#                                                    Employment      Country  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...     Slovakia
# 2                                          Student, full-time  Netherlands
#
#            US_State                                            EdLevel  \
# ResponseId
# 1               NaN  Secondary school (e.g. American high school, G...
# 2               NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                Age1stCode                                          LearnCode  \
# ResponseId
# 1           18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 2           11 - 17 years  Other online resources (ex: videos, blogs, etc...
#
#            YearsCode            DevType             OrgSize  \
# ResponseId
# ...

# %%
filt = df['Country'] == 'United States of America'
df.loc[filt]['EdLevel'].value_counts()
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          7315
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       2578
# Some college/university study without earning a degree                                2108
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    1107
# Associate degree (A.A., A.S., etc.)                                                    638
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             607
# Primary/elementary school                                                              551
# Something else                                                                         216
# Professional degree (JD, MD, etc.)                                                      95
# Name: EdLevel, dtype: int64

# %%
USA = df.loc[filt]['EdLevel'].value_counts()
USA
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          7315
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       2578
# Some college/university study without earning a degree                                2108
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    1107
# Associate degree (A.A., A.S., etc.)                                                    638
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             607
# Primary/elementary school                                                              551
# Something else                                                                         216
# Professional degree (JD, MD, etc.)                                                      95
# Name: EdLevel, dtype: int64

# %%
# clean text on EdLevel / replace with correct label

df["EdLevel"].replace({"Bachelor’s degree (B.A., B.S., B.Eng., etc.)": "Bachelor's Degree", 
                       "Master’s degree (M.A., M.S., M.Eng., MBA, etc.)": "Master's Degree", 
                       "Some college/university study without earning a degree)": "Some College", 
                       "Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)": "Secondary School",
                       "Associate degree (A.A., A.S., etc.)": "Associate Degree",
                       "Other doctoral degree (Ph.D., Ed.D., etc.)": "Other Doctoral Degree",
                       "Primary/elementary school)": "Elementary School",
                       "Professional degree (JD, MD, etc.)": "Professional Degree",}, inplace=True)

# %%
USA = df.loc[filt]['EdLevel'].value_counts()
USA
# Out:
# Bachelor's Degree                                         7315
# Master's Degree                                           2578
# Some college/university study without earning a degree    2108
# Secondary School                                          1107
# Associate Degree                                           638
# Other Doctoral Degree                                      607
# Primary/elementary school                                  551
# Something else                                             216
# Professional Degree                                         95
# Name: EdLevel, dtype: int64

# %%
import seaborn as sns

# %%
df.head(2)
# Out:
#                                     MainProfession  \
# ResponseId
# 1                   I am a developer by profession
# 2           I am a student who is learning to code
#
#                                                    Employment      Country  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...     Slovakia
# 2                                          Student, full-time  Netherlands
#
#            US_State            EdLevel     Age1stCode  \
# ResponseId
# 1               NaN   Secondary School  18 - 24 years
# 2               NaN  Bachelor's Degree  11 - 17 years
#
#                                                     LearnCode YearsCode  \
# ResponseId
# 1           Coding Bootcamp;Other online resources (ex: vi...       NaN
# 2           Other online resources (ex: videos, blogs, etc...         7
#
#                       DevType             OrgSize  \
# ResponseId
# 1           Developer, mobile  20 to 99 employees
# ...

# %%
# write this in order so that it will not get overlapping

sns.set_style('darkgrid')

# size of the chart

plt.figure(figsize=(50, 20), dpi=100)

# title of the chart

plt.title("Educational Level In USA", fontsize = 40)

# the x and y values on chart, pallette style used is set 2
# if you want to make it bar chart do below:
# US_EdLevel = sns.barplot(x=USA.index, y=USA.values,palette="Set2")

# make it horizontal chart. switch the axis.

US_EdLevel = sns.barplot(x=USA.values, y=USA.index,palette="Set2")

# label of x axis and its position (vertical)

US_EdLevel.tick_params(labelsize=30,rotation=0)

plt.xticks(rotation=0)

plt.xlabel('Count', fontsize=40) 

# the label above bar chart

US_EdLevel.bar_label(US_EdLevel.containers[0], label_type='edge', color='black', rotation=0, fontsize=30, padding=3)

# y label

plt.ylabel('Education Level', fontsize=40)

# show the chart

plt.show()

# %%
df.head(2)
# Out:
#                                     MainProfession  \
# ResponseId
# 1                   I am a developer by profession
# 2           I am a student who is learning to code
#
#                                                    Employment      Country  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...     Slovakia
# 2                                          Student, full-time  Netherlands
#
#            US_State            EdLevel     Age1stCode  \
# ResponseId
# 1               NaN   Secondary School  18 - 24 years
# 2               NaN  Bachelor's Degree  11 - 17 years
#
#                                                     LearnCode YearsCode  \
# ResponseId
# 1           Coding Bootcamp;Other online resources (ex: vi...       NaN
# 2           Other online resources (ex: videos, blogs, etc...         7
#
#                       DevType             OrgSize  \
# ResponseId
# 1           Developer, mobile  20 to 99 employees
# ...

# %%
country_grp = df.groupby(['Country'])
country_grp['EdLevel'].value_counts()
# Out:
# Country      EdLevel
# Afghanistan  Bachelor's Degree                                         21
#              Secondary School                                          10
#              Primary/elementary school                                  8
#              Some college/university study without earning a degree     6
#              Something else                                             6
#                                                                        ..
# Zimbabwe     Secondary School                                           5
#              Something else                                             2
#              Associate Degree                                           1
#              Master's Degree                                            1
#              Primary/elementary school                                  1
# Name: EdLevel, Length: 1163, dtype: int64

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.head(2)
# Out:
#                                     MainProfession  \
# ResponseId
# 1                   I am a developer by profession
# 2           I am a student who is learning to code
#
#                                                    Employment      Country  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...     Slovakia
# 2                                          Student, full-time  Netherlands
#
#            US_State            EdLevel     Age1stCode  \
# ResponseId
# 1               NaN   Secondary School  18 - 24 years
# 2               NaN  Bachelor's Degree  11 - 17 years
#
#                                                     LearnCode YearsCode  \
# ResponseId
# 1           Coding Bootcamp;Other online resources (ex: vi...       NaN
# 2           Other online resources (ex: videos, blogs, etc...         7
#
#                       DevType             OrgSize  \
# ResponseId
# 1           Developer, mobile  20 to 99 employees
# ...

# %%
agg_tips = tips.groupby(['day','sex'])['tip'].sum().unstack().fillna(0)
agg_tips
# Out:
# sex     Male  Female
# day
# Thur   89.41   82.42
# Fri    26.93   25.03
# Sat   181.95   78.45
# Sun   186.78   60.61

# %%
agg_tips.plot(kind='bar',stacked=True)
# Out:
# <AxesSubplot:xlabel='day'>

# %%
b = df['Country'].value_counts().head(5).sort_values(ascending=False)
b
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
# Name: Country, dtype: int64

# %%
from matplotlib.pyplot import figure

# %%
countries = ['United States of America','India','Germany','United Kingdom of Great Britain and Northern Ireland','Canada']
b = df[df["Country"].isin(countries)]
b.head()
# Out:
#                                     MainProfession  \
# ResponseId
# 5                   I am a developer by profession
# 6           I am a student who is learning to code
# 7                      I code primarily as a hobby
# 9                   I am a developer by profession
# 11                  I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 5           Independent contractor, freelancer, or self-em...
# 6                                          Student, part-time
# 7                                         I prefer not to say
# 9                                          Employed part-time
# 11                                         Employed full-time
#
#                                                       Country       US_State  \
# ResponseId
# 5           United Kingdom of Great Britain and Northern I...            NaN
# 6                                    United States of America        Georgia
# ...

# %%
df.head(2)
# Out:
#                                     MainProfession  \
# ResponseId
# 1                   I am a developer by profession
# 2           I am a student who is learning to code
#
#                                                    Employment      Country  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...     Slovakia
# 2                                          Student, full-time  Netherlands
#
#            US_State            EdLevel     Age1stCode  \
# ResponseId
# 1               NaN   Secondary School  18 - 24 years
# 2               NaN  Bachelor's Degree  11 - 17 years
#
#                                                     LearnCode YearsCode  \
# ResponseId
# 1           Coding Bootcamp;Other online resources (ex: vi...       NaN
# 2           Other online resources (ex: videos, blogs, etc...         7
#
#                       DevType             OrgSize  \
# ResponseId
# 1           Developer, mobile  20 to 99 employees
# ...

# %%
c = b.groupby(['Country','EdLevel'])['EdLevel'].count().unstack().fillna(0)
c
# Out:
# EdLevel                                             Associate Degree  \
# Country
# Canada                                                           182
# Germany                                                          123
# India                                                             26
# United Kingdom of Great Britain and Northern Ir...                84
# United States of America                                         638
#
# EdLevel                                             Bachelor's Degree  \
# Country
# Canada                                                           1284
# Germany                                                          1514
# India                                                            6308
# United Kingdom of Great Britain and Northern Ir...               1816
# United States of America                                         7315
#
# EdLevel                                             Master's Degree  \
# Country
# ...

# %%
c.to_excel('/Users/jean110284/Desktop/Everything/MJUPython/StackedBar.xlsx')

# %%
df.head(2)
# Out:
#                                     MainProfession  \
# ResponseId
# 1                   I am a developer by profession
# 2           I am a student who is learning to code
#
#                                                    Employment      Country  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...     Slovakia
# 2                                          Student, full-time  Netherlands
#
#            US_State            EdLevel     Age1stCode  \
# ResponseId
# 1               NaN   Secondary School  18 - 24 years
# 2               NaN  Bachelor's Degree  11 - 17 years
#
#                                                     LearnCode YearsCode  \
# ResponseId
# 1           Coding Bootcamp;Other online resources (ex: vi...       NaN
# 2           Other online resources (ex: videos, blogs, etc...         7
#
#                       DevType             OrgSize  \
# ResponseId
# 1           Developer, mobile  20 to 99 employees
# ...

# %%
plt.rcParams["figure.figsize"] = (30,20)
c.plot(kind='bar',stacked=True)

plt.xticks(rotation=90, fontsize = 20)
plt.yticks(rotation=0, fontsize = 20)
plt.xlabel('Country', fontsize=30) 
plt.ylabel('Education Level Count', fontsize=30)
plt.legend(fontsize=20)
plt.title('Education Level Count in Top 10 Countries',fontsize=30)
# Out:
# Text(0.5, 1.0, 'Education Level Count in Top 10 Countries')

# %%
import numpy as np
import seaborn as sns
import plotly.express as px

# %%
import numpy as np
import matplotlib.pyplot as plt

A = [45, 17, 47]
B = [91, 70, 72]

fig = plt.figure(facecolor="white")

ax = fig.add_subplot(1, 1, 1)
bar_width = 0.5
bar_l = np.arange(1, 4)
tick_pos = [i + (bar_width / 2) for i in bar_l]

ax1 = ax.bar(bar_l, A, width=bar_width, label="A", color="green")
ax2 = ax.bar(bar_l, B, bottom=A, width=bar_width, label="B", color="blue")
ax.set_ylabel("Count", fontsize=18)
ax.set_xlabel("Class", fontsize=18)
ax.legend(loc="best")
plt.xticks(tick_pos, ["C1", "C2", "C3"], fontsize=16)
plt.yticks(fontsize=16)

for r1, r2 in zip(ax1, ax2):
    h1 = r1.get_height()
    h2 = r2.get_height()
    plt.text(r1.get_x() + r1.get_width() / 2., h1 / 2., "%d" % h1, ha="center", va="bottom", color="white", fontsize=16, fontweight="bold")
    plt.text(r2.get_x() + r2.get_width() / 2., h1 + h2 / 2., "%d" % h2, ha="center", va="bottom", color="white", fontsize=16, fontweight="bold")

plt.show()

# %%
# %matplotlib inline

import pandas as pd


# Save the chart that's drawn
ax = c.plot(stacked=True, kind='bar', figsize=(30, 25))



# .patches is everything inside of the chart, lines and
# rectangles and circles and stuff. In this case we only
# have rectangles!
for rect in ax.patches:
    # Find where everything is located
    height = rect.get_height()
    width = rect.get_width()
    x = rect.get_x()
    y = rect.get_y()
    
    # The width of the bar is also not pixels, it's the
    # number of animals. So we can use it as the label!
    label_text = width
    
    # ax.text(x, y, text)
    label_x = x + width / 2
    label_y = y + height / 2
    ax.text(label_x, label_y, label_text, ha='center', va='center', fontsize= 30)


plt.xticks(rotation=90, fontsize = 30)
plt.yticks(rotation=0, fontsize = 30)
plt.xlabel('Country', fontsize=50) 
plt.ylabel('Education Level Count', fontsize=50)
plt.legend(fontsize=30)
plt.title('Education Level Count in Top 10 Countries',fontsize=40)
# Out:
# Text(0.5, 1.0, 'Education Level Count in Top 10 Countries')

# %%
# replace the "unwanted character" with "apostrophe" on EdLevel column
# to make it something like "Bachelor's Degree"

df['EdLevel'] = df['EdLevel'].replace({'‚Äô':"'"})
df.head(2)
# Out:
#                                     MainProfession  \
# ResponseId
# 1                   I am a developer by profession
# 2           I am a student who is learning to code
#
#                                                    Employment      Country  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...     Slovakia
# 2                                          Student, full-time  Netherlands
#
#            US_State            EdLevel     Age1stCode  \
# ResponseId
# 1               NaN   Secondary School  18 - 24 years
# 2               NaN  Bachelor's Degree  11 - 17 years
#
#                                                     LearnCode YearsCode  \
# ResponseId
# 1           Coding Bootcamp;Other online resources (ex: vi...       NaN
# 2           Other online resources (ex: videos, blogs, etc...         7
#
#                       DevType             OrgSize  \
# ResponseId
# 1           Developer, mobile  20 to 99 employees
# ...

# %%
# if changes is correct and satisfied with it put inplace = True

# df['EdLevel'] = df['EdLevel'].replace({'‚Äô':"'"}, inplace = True)
# df.head(2)

# %%
df['Age1stCode']
# Out:
# ResponseId
# 1        18 - 24 years
# 2        11 - 17 years
# 3        11 - 17 years
# 4        11 - 17 years
# 5         5 - 10 years
#              ...
# 83435    11 - 17 years
# 83436    11 - 17 years
# 83437    11 - 17 years
# 83438    11 - 17 years
# 83439    11 - 17 years
# Name: Age1stCode, Length: 83439, dtype: object

# %%
(df['Age1stCode'].unique())
# Out:
# array(['18 - 24 years', '11 - 17 years', '5 - 10 years', '25 - 34 years',
#        '35 - 44 years', 'Younger than 5 years', '45 - 54 years',
#        '55 - 64 years', nan, 'Older than 64 years'], dtype=object)

# %%
# create a pareto chart for Age1stCode

myField = df['Age1stCode']

myFreq = myField.value_counts()

myKeys = myFreq.keys()

myVals = myFreq.values

myFreqTable = pd.DataFrame({'Age1stCode': myKeys, 'Frequency': myVals})

myFreqTable['Percent'] = myFreqTable['Frequency']/myFreqTable['Frequency'].sum()*100

myFreqTable
# Out:
#              Age1stCode  Frequency    Percent
# 0         11 - 17 years      44170  53.061519
# 1         18 - 24 years      20065  24.104129
# 2          5 - 10 years      11720  14.079262
# 3         25 - 34 years       4199   5.044268
# 4         35 - 44 years       1312   1.576109
# 5  Younger than 5 years        905   1.087179
# 6         45 - 54 years        544   0.653508
# 7         55 - 64 years        245   0.294319
# 8   Older than 64 years         83   0.099708

# %%
df.head(2)
# Out:
#                                     MainProfession  \
# ResponseId
# 1                   I am a developer by profession
# 2           I am a student who is learning to code
#
#                                                    Employment      Country  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...     Slovakia
# 2                                          Student, full-time  Netherlands
#
#            US_State            EdLevel     Age1stCode  \
# ResponseId
# 1               NaN   Secondary School  18 - 24 years
# 2               NaN  Bachelor's Degree  11 - 17 years
#
#                                                     LearnCode YearsCode  \
# ResponseId
# 1           Coding Bootcamp;Other online resources (ex: vi...       NaN
# 2           Other online resources (ex: videos, blogs, etc...         7
#
#                       DevType             OrgSize  \
# ResponseId
# 1           Developer, mobile  20 to 99 employees
# ...

# %%
# modify some of the age if needed

df['Age1stCode'] = df['Age1stCode'].replace({'0 - 5 years':"5 years below",
                                             
                                             
                                            '64 - up years':"64 years up"})
df.head(2)
# Out:
#                                     MainProfession  \
# ResponseId
# 1                   I am a developer by profession
# 2           I am a student who is learning to code
#
#                                                    Employment      Country  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...     Slovakia
# 2                                          Student, full-time  Netherlands
#
#            US_State            EdLevel     Age1stCode  \
# ResponseId
# 1               NaN   Secondary School  18 - 24 years
# 2               NaN  Bachelor's Degree  11 - 17 years
#
#                                                     LearnCode YearsCode  \
# ResponseId
# 1           Coding Bootcamp;Other online resources (ex: vi...       NaN
# 2           Other online resources (ex: videos, blogs, etc...         7
#
#                       DevType             OrgSize  \
# ResponseId
# 1           Developer, mobile  20 to 99 employees
# ...

# %%
# sort the values

myFreqTable = myFreqTable.sort_values(by=['Frequency'],ascending=False)

# drop old index and replace a new / default one

myFreqTable = myFreqTable.reset_index(drop=True)

myFreqTable
# Out:
#              Age1stCode  Frequency    Percent
# 0         11 - 17 years      44170  53.061519
# 1         18 - 24 years      20065  24.104129
# 2          5 - 10 years      11720  14.079262
# 3         25 - 34 years       4199   5.044268
# 4         35 - 44 years       1312   1.576109
# 5  Younger than 5 years        905   1.087179
# 6         45 - 54 years        544   0.653508
# 7         55 - 64 years        245   0.294319
# 8   Older than 64 years         83   0.099708

# %%
# cumulative percentage

myFreqTable['Cumulative Percent'] = myFreqTable['Frequency'].cumsum()/myFreqTable['Frequency'].sum()*100
myFreqTable
# Out:
#              Age1stCode  Frequency    Percent  Cumulative Percent
# 0         11 - 17 years      44170  53.061519           53.061519
# 1         18 - 24 years      20065  24.104129           77.165648
# 2          5 - 10 years      11720  14.079262           91.244909
# 3         25 - 34 years       4199   5.044268           96.289177
# 4         35 - 44 years       1312   1.576109           97.865286
# 5  Younger than 5 years        905   1.087179           98.952464
# 6         45 - 54 years        544   0.653508           99.605973
# 7         55 - 64 years        245   0.294319           99.900292
# 8   Older than 64 years         83   0.099708          100.000000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt


labels = ['A', 'B', 'C']
values = [150, 80, 10]


fig, ax = plt.subplots()

ax.barh(labels, values)

for i, value in enumerate(values):
    ax.text(value + 3, i, str(value))
xmin, xmax = ax.get_xlim()
ax.set_xlim(xmin, 1.1*xmax)

plt.show()

# %%
# get first the x and y columns on a dataframe

plt.figure(figsize=(30, 10), dpi=100)

y = myFreqTable['Frequency']
x = myFreqTable['Age1stCode']

# create a bar chart

barplot = plt.bar(x,y)


for bar in barplot:
    yval = bar.get_height() 
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, int(yval), va='bottom') #va: vertical alignment y positional argument

# %%
# cumulative percentage

myFreqTable['Cumulative Percent'] = myFreqTable['Frequency'].cumsum()/myFreqTable['Frequency'].sum()*100
myFreqTable
# Out:
#              Age1stCode  Frequency    Percent  Cumulative Percent
# 0         11 - 17 years      44170  53.061519           53.061519
# 1         18 - 24 years      20065  24.104129           77.165648
# 2          5 - 10 years      11720  14.079262           91.244909
# 3         25 - 34 years       4199   5.044268           96.289177
# 4         35 - 44 years       1312   1.576109           97.865286
# 5  Younger than 5 years        905   1.087179           98.952464
# 6         45 - 54 years        544   0.653508           99.605973
# 7         55 - 64 years        245   0.294319           99.900292
# 8   Older than 64 years         83   0.099708          100.000000

# %%
# create a dataframe
# dataframe is myFreqTable

y = myFreqTable['Frequency']
x = myFreqTable['Age1stCode']

# title of chart

title = 'Pareto Chart'

# size of chart

plt.figure(figsize=(19, 10))

# bar chart

axes1 = plt.subplot()

b = axes1.bar(myFreqTable['Age1stCode'], myFreqTable['Frequency'], label='Age1stCode')

plt.xticks(rotation=90)

# use twinx() function to create the second axis object “ax2”

axes2 = axes1.twinx()

p = axes2.plot(myFreqTable['Age1stCode'], myFreqTable['Cumulative Percent'], c='r', marker='o', zorder=5, label='Cumulative Percentage')

axes1.legend(handles=(b, p[0]), loc='center right', fontsize=15)

plt.xticks(rotation=0, fontsize = 15)
plt.yticks(rotation=0, fontsize = 10)
plt.xlabel('Age1stCode', fontsize=15) 
plt.ylabel('Frequency', fontsize=15)
plt.title('Age First Code',fontsize=15)

plt.show()

# %%
# make a histogram for AgefirstCode

df['Age1stCode'].hist()
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns
import numpy as np

# %%
plt.style.use('seaborn')

# %%
# dataset

hist = df['Age1stCode'].hist(edgecolor='black')

plt.xticks(rotation=90)
plt.xlabel("Age")
plt.ylabel("Age Count", loc="center")
plt.title = ("Age First Code")

plt.show()

# %%
import dash
from dash import html

# %%
pip install xlwt openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
myFreqTable.to_excel('/Users/jean110284/Desktop/Everything/MJUPython/MyFreqTable.xlsx')

# %%
df.head(2)
# Out:
#                                     MainProfession  \
# ResponseId
# 1                   I am a developer by profession
# 2           I am a student who is learning to code
#
#                                                    Employment      Country  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...     Slovakia
# 2                                          Student, full-time  Netherlands
#
#            US_State            EdLevel     Age1stCode  \
# ResponseId
# 1               NaN   Secondary School  18 - 24 years
# 2               NaN  Bachelor's Degree  11 - 17 years
#
#                                                     LearnCode YearsCode  \
# ResponseId
# 1           Coding Bootcamp;Other online resources (ex: vi...       NaN
# 2           Other online resources (ex: videos, blogs, etc...         7
#
#                       DevType             OrgSize  \
# ResponseId
# 1           Developer, mobile  20 to 99 employees
# ...

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp['YearlySalary'].max()
# Out:
# Country
# Afghanistan                             30468516.0
# Albania                                   692042.0
# Algeria                                    48550.0
# Andorra                                   146981.0
# Angola                                     96000.0
#                                            ...
# Venezuela, Bolivarian Republic of...      229596.0
# Viet Nam                                  258744.0
# Yemen                                      19176.0
# Zambia                                    105000.0
# Zimbabwe                                   36000.0
# Name: YearlySalary, Length: 181, dtype: float64

# %%
edlevel_grp = df.groupby(['EdLevel'])

# %%
edlevel_grp['YearlySalary'].max()
# Out:
# EdLevel
# Associate Degree                                           5750000.0
# Bachelor's Degree                                         20000000.0
# Master's Degree                                           30468516.0
# Other Doctoral Degree                                      6226452.0
# Primary/elementary school                                 45241312.0
# Professional Degree                                       15000000.0
# Secondary School                                           4916050.0
# Some college/university study without earning a degree    21822250.0
# Something else                                             2164632.0
# Name: YearlySalary, dtype: float64

# %%
df.head()
# Out:
#                                                MainProfession  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
#
#                                                       Country US_State  \
# ResponseId
# 1                                                    Slovakia      NaN
# ...

# %%
edlevel_grp = df.groupby(['EdLevel'])
edlevel_grp['YearlySalary'].min()
# Out:
# EdLevel
# Associate Degree                                           3.0
# Bachelor's Degree                                          1.0
# Master's Degree                                            1.0
# Other Doctoral Degree                                     48.0
# Primary/elementary school                                  2.0
# Professional Degree                                       24.0
# Secondary School                                           4.0
# Some college/university study without earning a degree     5.0
# Something else                                            10.0
# Name: YearlySalary, dtype: float64

# %%
edlevel_grp = df.groupby(['EdLevel'])
edlevel_grp['YearlySalary'].mean()
# Out:
# EdLevel
# Associate Degree                                          107474.258459
# Bachelor's Degree                                         125598.013194
# Master's Degree                                           117672.494561
# Other Doctoral Degree                                     128650.713948
# Primary/elementary school                                 282842.750000
# Professional Degree                                        87416.327478
# Secondary School                                           78298.884973
# Some college/university study without earning a degree    106301.956263
# Something else                                             75847.989540
# Name: YearlySalary, dtype: float64

# %%
edlevel_grp = df.groupby(['EdLevel'])
edlevel_grp['YearlySalary'].median()
# Out:
# EdLevel
# Associate Degree                                          56720.0
# Bachelor's Degree                                         54972.0
# Master's Degree                                           60744.0
# Other Doctoral Degree                                     77556.0
# Primary/elementary school                                 49050.0
# Professional Degree                                       37752.0
# Secondary School                                          41568.0
# Some college/university study without earning a degree    51887.0
# Something else                                            47563.0
# Name: YearlySalary, dtype: float64
